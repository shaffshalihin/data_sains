# %% [markdown]
# <a href="https://colab.research.google.com/github/shaffshalihin/data_sains/blob/main/Tugas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list -s "Iris"
# Out:
# ref                                                        title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# uciml/iris                                                 Iris Species                                        4KB  2016-09-27 07:38:05         434165       3443  0.7941176
# arshid/iris-flower-dataset                                 Iris Flower Dataset                               1010B  2018-03-22 15:18:06         112200        709  0.8235294
# himanshunakrani/iris-dataset                               Iris dataset                                      1006B  2022-07-20 18:50:06           7078         56  1.0
# ...

# %%
# !kaggle datasets download chuckyin/iris-datasets --unzip
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/kaggle", line 5, in <module>
#     from kaggle.cli import main
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/__init__.py", line 23, in <module>
#     api.authenticate()
#   File "/usr/local/lib/python3.10/dist-packages/kaggle/api/kaggle_api_extended.py", line 403, in authenticate
#     raise IOError('Could not find {}. Make sure it\'s located in'
# OSError: Could not find kaggle.json. Make sure it's located in /root/.kaggle. Or use the environment method.

# %%
import pandas as pd
import numpy as np

# %%
dataset = "/content/Iris.csv"
df = pd.read_csv(dataset)
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
jumlah_baris, jumlah_kolom = df.shape
print("jumlah baris:", jumlah_baris)
print("jumlah kolom:", jumlah_kolom)
# Out:
# jumlah baris: 150
# jumlah kolom: 6

# %%
kolom_species = df.iloc[:,-1]
kolom_id = df.iloc[:,0]
dataset2 = {"Id" : kolom_id, "Species" : kolom_species}

df2= pd.DataFrame(dataset2)
df2
# Out:
#       Id         Species
# 0      1     Iris-setosa
# 1      2     Iris-setosa
# 2      3     Iris-setosa
# 3      4     Iris-setosa
# 4      5     Iris-setosa
# ..   ...             ...
# 145  146  Iris-virginica
# 146  147  Iris-virginica
# 147  148  Iris-virginica
# 148  149  Iris-virginica
# 149  150  Iris-virginica
#
# [150 rows x 2 columns]

# %%
df.head(10)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
df2 = df2.iloc[11:16, :]
df2
# Out:
#     Id      Species
# 11  12  Iris-setosa
# 12  13  Iris-setosa
# 13  14  Iris-setosa
# 14  15  Iris-setosa
# 15  16  Iris-setosa

# %%
df.head(9)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa

# %%
df.tail(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.corr()
# Out:
# <ipython-input-173-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
korelasi = df["PetalLengthCm"].corr(df["PetalWidthCm"])
korelasi
# Out:
# 0.9627570970509663

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.describe(include="object")
# Out:
#             Species
# count           150
# unique            3
# top     Iris-setosa
# freq             50

# %%
df.describe(include="all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
df.mean()
# Out:
# <ipython-input-178-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
df["PetalLengthCm"].mean()
# Out:
# 3.758666666666666

# %%
df["SepalWidthCm"].min()
# Out:
# 2.0

# %%
df.groupby("Species")["SepalLengthCm"].mean()
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
data_species = df["Species"].value_counts()

df_species = pd.DataFrame({"kategori" : data_species.index, "jumlah" : data_species.values})
df_species
# Out:
#           kategori  jumlah
# 0      Iris-setosa      50
# 1  Iris-versicolor      50
# 2   Iris-virginica      50

# %%
data_PetalLengthCm = df["PetalLengthCm"].value_counts()

df_PetalLengthCm = pd.DataFrame({"kategori" : data_PetalLengthCm.index, "jumlah" : data_PetalLengthCm.values })
df_PetalLengthCm
# Out:
#     kategori  jumlah
# 0        1.5      14
# 1        1.4      12
# 2        5.1       8
# 3        4.5       8
# 4        1.6       7
# 5        1.3       7
# 6        5.6       6
# 7        4.7       5
# 8        4.9       5
# 9        4.0       5
# 10       4.2       4
# 11       5.0       4
# 12       4.4       4
# 13       4.8       4
# 14       1.7       4
# 15       3.9       3
# 16       4.6       3
# 17       5.7       3
# 18       4.1       3
# 19       5.5       3
# 20       6.1       3
# 21       5.8       3
# 22       3.3       2
# 23       5.4       2
# 24       6.7       2
# 25       5.3       2
# 26       5.9       2
# 27       6.0       2
# 28       1.2       2
# 29       4.3       2
# 30       1.9       2
# 31       3.5       2
# 32       5.2       2
# 33       3.0       1
# 34       1.1       1
# 35       3.7       1
# 36       3.8       1
# 37       6.6       1
# 38       6.3       1
# 39       1.0       1
# 40       6.9       1
# 41       3.6       1
# ...
